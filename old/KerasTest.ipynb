# %%
from keras.models import Sequential # Tells you which is the backend used (i.e. Tensorflow)
from keras.layers import Dense  # The same Keras code is used for each backend.
from keras.optimizers import Adam, SGD
model = Sequential() # linear stack of layers
model.add(Dense(1, input_shape=(121,))) # 1 output, 1 input
model.summary() # bias is included in parameter count
model.compile(Adam(lr=0.1), 'mean_squared_error') # Important - Builds the model
model.fit(X, y, epochs=100) # first to input and output
y_pred = model.predict(X) # Get a y_prediction for each X

# Get the model weights
W, B = model.get_weights()

from sklearn import datasets

iris = datasets.load_iris()

X = datasets.iloc[:,1:5].values
y = datasets.iloc[:,5].values

from sklearn.preprocessing import LabelEncoder
encoder =  LabelEncoder()
y1 = encoder.fit_transform(y)

Y = pd.get_dummies(y1).values


from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0) 

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()

model.add(Dense(10,input_shape=(4,),activation='tanh'))
model.add(Dense(8,activation='tanh'))
model.add(Dense(6,activation='tanh'))
model.add(Dense(3,activation='softmax'))

model.compile(Adam(lr=0.04),'categorical_crossentropy',metrics=['accuracy'])

model.summary()

model.fit(X, y, epochs=200)


y_pred = model.predict(X) # Get a y_prediction for each X

# Get the model weights
W, B = model.get_weights()


from sklearn.linear_model import LogisticRegression
my_linreg = LogisticRegression()

# fitting the model to the training data:
my_linreg.fit(X, y)
y_pred = my_linreg.predict(X)
error = accuracy_score(y, y_pred)

print(error)
