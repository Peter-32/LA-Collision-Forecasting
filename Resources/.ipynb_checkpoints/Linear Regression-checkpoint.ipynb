# %% [markdown]
# # HOMEWORK 3

# %% [markdown]
# ### QUESTION 1

# %% [markdown]
# #### Step1: Importing the sklearn class (machine learning algorithm) that you would like to use for modeling:

# %%
# Numpy is a library for performing advanced mathematical operations on Arrays
# import the pandas library:
# Pandas is a powerful library to read and process data tables
import numpy as np
# it means that we can use abbreviation "np" from now on to refer to numpy functions 
import pandas as pd

# %%
##Step1: Importing the sklearn class (machine learning algorithm) that you would like to use for modeling:
# The following lines will import LogisticRegression, KNeighborsClassifier "Class" and DecisionTreeClassifier Classes
# "LogisticRegression" and "DecisionTreeClassifier" are the names of a "sklearn classes" to perform Logistic Regression and Decision Tree based Classification
# KNeighborsClassifier is name of a "sklearn class" to perform "KNN Classification"

# %% [markdown]
# #### Step2: Set up the Feature Matrix and Label Vector:

# %%
# loading a CSV file from local device and store it in a pandas DataFrame:
# "read_csv" is a pandas function to read csv files from web or local device:

df = pd.DataFrame()
NDF = pd.DataFrame()

df = pd.read_csv('/Users/cherylmariajose/Desktop/cs4661/HW3/Credit.csv')

# %% [markdown]
# ### Features:
# - **Income:** Monthly Income in 1000 dollars
# - **Limit:** Credit limit
# - **Rating:** Credit rating
# - **Cards:** No. of credit cards
# - **Age:** Individual age
# - **Education:** Years of education
# - **Married:** Marital Status
#
# ### Target:
# - **Balance:** Avg credit card debt for an individual

# %%
# displaying the DataFrame:
# you can also use print(df)
df
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Married  Balance
# 0     14.891   3606     283      2   34         11        1      333
# 1    106.025   6645     483      3   82         15        1      903
# 2    104.593   7075     514      4   71         11        0      580
# 3    148.924   9504     681      3   36         11        0      964
# 4     55.882   4897     357      2   68         16        1      331
# 5     80.180   8047     569      4   77         10        0     1151
# 6     20.996   3388     259      2   37         12        0      203
# 7     71.408   7114     512      2   87          9        0      872
# 8     15.125   3300     266      5   66         13        0      279
# 9     71.061   6819     491      3   41         19        1     1350
# 10    63.095   8117     589      4   30         14        1     1407
# 11    15.045   1311     138      3   64         16        0        0
# 12    80.616   5308     394      1   57          7        1      204
# ...

# %%
# this line print the size of heart_s.data (heart feature matrix) 
#(303 samples and 10 features)
print(df.shape)
# Out:
# (400, 8)

# %%
# checking the dataset by printing every 10 lines:
df[0::10]
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Married  Balance
# 0     14.891   3606     283      2   34         11        1      333
# 10    63.095   8117     589      4   30         14        1     1407
# 20    17.700   2860     235      4   63         16        0       89
# 30    34.142   5666     413      4   47          5        1      863
# 40    34.950   3327     253      3   54         14        0       50
# 50    36.362   5183     376      3   49         15        1      654
# 60    35.510   5198     364      2   35         20        0      631
# 70    24.889   3954     318      4   75         12        1      357
# 80    27.369   3449     288      3   40          9        1      162
# 90    20.191   5767     431      4   42         16        1     1023
# 100   21.153   3736     256      1   41         11        0      298
# 110   34.537   3271     250      3   57         17        1       47
# 120   27.241   1402     128      2   67         15        1        0
# ...

# %% [markdown]
# ### Normalising the data

# %%
# Creating the Feature Matrix for iris dataset:

# create a python list of feature names that would like to pick from the dataset:
feature_cols = ['Income','Limit','Rating','Cards','Age','Education','Married']


for k in feature_cols:
    print(k)
    vmax = df[k].max()
    print(vmax)
    NDF[k] = df[k]/vmax
# Out:
# Income
# 186.634
# Limit
# 13913
# Rating
# 982
# Cards
# 9
# Age
# 98
# Education
# 20
# Married
# 1

# %% [markdown]
# ### Preparing Feature Matrix X and Target Vector y:

# %%
# use the above list to select the features from the original DataFrame
X = NDF[feature_cols]

# %%
# print the first 5 rows
X.head()
# Out:
#      Income     Limit    Rating     Cards       Age  Education  Married
# 0  0.079787  0.259182  0.288187  0.222222  0.346939       0.55      1.0
# 1  0.568090  0.477611  0.491853  0.333333  0.836735       0.75      1.0
# 2  0.560418  0.508517  0.523422  0.444444  0.724490       0.55      0.0
# 3  0.797947  0.683102  0.693483  0.333333  0.367347       0.55      0.0
# 4  0.299420  0.351973  0.363544  0.222222  0.693878       0.80      1.0

# %%
# this line print the size of heart_s.data (heart feature matrix) 
#(303 samples and 7 features)
print(X.shape)
# Out:
# (400, 7)

# %%
# select a Series of labels (the last column) from the DataFrame
y = df['Balance']

# %%
# checking the label vector by printing every 10 values
y[::10]
# Out:
# 0       333
# 10     1407
# 20       89
# 30      863
# 40       50
# 50      654
# 60      631
# 70      357
# 80      162
# 90     1023
# 100     298
# 110      47
# 120       0
# 130     868
# 140    1425
# 150     581
# 160     836
# 170       0
# 180     423
# 190     538
# 200     829
# 210      95
# 220    1246
# 230     661
# 240     148
# 250       0
# 260     345
# 270     136
# 280     541
# 290     159
# 300     580
# 310    1036
# 320       5
# 330    1054
# 340     320
# 350       0
# 360     712
# 370     992
# 380     661
# 390    1393
# Name: Balance, dtype: int64

# %% [markdown]
# ## Evaluating the accuracy of our classifier:
#
# #### We split the data into training and testing sets. Then, assuming that we do NOT know the label of Testing Set, we train our model on Training Set and then test it on Testing Set. Then, we compare the "predicted labels" against the "actual labels" to check the accuracy.

# %%
# Randomly splitting the original dataset into training set and testing set
# The function"train_test_split" from "sklearn.cross_validation" library performs random splitting.
# "test_size=0.2" means that pick 20% of data samples for testing set, and the rest (80%) for training set.

from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
# checking the size of target vector:
y.size
# Out:
# 400

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (320, 7)
# (320,)
# (80, 7)
# (80,)

# %% [markdown]
#
# ###  LINEAR REGRESSION:

# %%
# The following line will import LinearRegression "Class"

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Instantiating and Training Stage:

# %%
# In the following line, "my_linreg" is instantiated as an "object" of LinearRegression "class". 

my_linreg = LinearRegression()

# fitting the model to the training data:
my_linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# printing Theta0 using attribute "intercept_":
print(my_linreg.intercept_)

# printing [Theta1, Theta2, Theta3, Theta4, Theta5, Theta6, Theta7] using attribute "coef_":
print(my_linreg.coef_)
# Out:
# -451.390136282
# [-1413.47222539  1357.75410875  2441.3004289    103.52548744  -102.02433542
#     40.34044338   -48.45522561]

# %% [markdown]
# ### Thus, our predictive model will be:
# $$y = (-451.39013628242) + (-1413.47222539)\times Income + 1357.75410875\times Limit + 2441.3004289 \times Rating + 103.52548744 \times Cards + (-102.024335)\times Age + 40.34044338 \times Education (-48.45522561)\times Married$$

# %% [markdown]
# ### The most important feature is Rating
# ### The most important feature is Education

# %% [markdown]
# ### Testing and Prediction Stage:

# %%
# make predictions on the testing set
y_prediction = my_linreg.predict(X_test)

print(y_prediction)
# Out:
# [  187.83259081   696.19359653  1008.45870602   602.54553619  1005.89421809
#    689.53276161   912.63981066   265.93761365   921.40430581  1097.28246448
#    561.24806805   347.10203229   793.92182702   133.99552456   831.68509878
#    154.29201659  1391.55139882  -127.61911507   946.8333401    719.02865483
#    593.49954528    82.58696538    75.58160302   -69.92762404   480.22371194
#   -153.93316298   290.58134942   588.66521868   908.95132202   887.83016569
#   -215.31132242   421.56659575    31.96584993  -265.81389094   925.49231108
#   1229.55288913   382.92814713   934.30680369  1763.56079475   845.73667161
#    810.02069387   502.35960813   380.43477228   448.20831629   673.02981403
#    492.00309225   589.86815721  1092.19775167   521.63311942   689.99089979
#    799.4973836    265.38602315  1542.56678822  1188.82234981   303.81822799
#    848.83393296  -152.65676468   634.77873681   266.10574461   828.42364016
# ...

# %% [markdown]
# #
# # Evaluation for Regression:
#
# - In regression, the target is continous valued. So, we need to find the error as the average difference between the "predicted target value" and the "actual value".
# - The most popular metric to quantify this difference (error) is **Root Mean Square Error** or **RMSE**:
#
# $$RMSE = \sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
# - Notice that **RMSE** is error. So, unlike the accuracy for classifiers, **a lower value for RMSE is better!**

# %%
from sklearn import metrics
import numpy as np

# Calculating "Mean Square Error" (MSE):
mse = metrics.mean_squared_error(y_test, y_prediction)

# Using numpy sqrt function to take the square root and calculate "Root Mean Square Error" (RMSE)
rmse = np.sqrt(mse)

print(rmse)
# Out:
# 154.410746767

# %% [markdown]
# ## Cross-Validation in sklearn

# %%
# importing the method:
from sklearn.cross_validation import cross_val_score

# %% [markdown]
# ### Applying 10-fold Cross Validation for "logistic regression" classifier:

# %%
# Applying 10-fold cross validation with "linear regression":
 
mse_list = cross_val_score(my_linreg, X, y, cv=10, scoring='mean_squared_error')

print(mse_list)
# Out:
# [-23646.90415343 -32003.04401232 -35462.64435619 -37327.60719635
#  -14341.32205939 -33628.37104224 -31631.99317834 -12491.00334951
#  -20749.61212175 -23204.94743459]

# %% [markdown]
# #### As you see, we would like to check the "mean_squared_error" (mse) for linear regression
# #### Notice that "cross_val_score" by default provides "negative" values for "mse" to clarify that mse is error. In order to calculate root mean square error (rmse), we have to make them positive, and then find the avergae of them!

# %%
# Notice that "cross_val_score" by default provides "negative" values for "mse" to clarify that mse is error.
# in order to calculate root mean square error (rmse), we have to make them positive!
mse_list_positive = -mse_list

# using numpy sqrt function to calculate rmse:
rmse_list = np.sqrt(mse_list_positive)
print(rmse_list)
# Out:
# [ 153.7754992   178.89394627  188.31527914  193.20353826  119.75525901
#   183.38039983  177.85385343  111.76315739  144.04725656  152.331702  ]

# %%
# calculate the average RMSE as final result of cross validation:
print(rmse_list.mean())
# Out:
# 160.331989107

# %% [markdown]
# ## QUESTION 2

# %% [markdown]
# ### Thus, our predictive model will be:
# $$y = 30 + 20\times GPA + 0.07\times Age + (-30) \times Position + 0.01\times GPA\times Age + 10\times GPA\times Position$$

# %% [markdown]
# ### Part A

# %% [markdown]
# ### i) For a fixed value of age and gpa, technical positions earn more than non-technical positions
#
# #### False. Because :
# $$y= 30 + 20\times 2.5 + 0.07\times 27 + (-30) \times 1 + 0.01\times 2.5\times 27 + 10\times 2.5\times 1$$
#
# $$y= 77.565$$
# #### For Non-Technical
# $$y= 30 + 20\times 2.5 + 0.07\times 27 + (-30) \times 0 + 0.01\times 2.5\times 27 + 10\times 2.5\times 0$$
#
# $$y= 82.565$$
#
# ### ii) For a fixed value of age and gpa, non-technical positions earn more than non-technical positions
#
# #### False. Because :
# #### For Technical
# $$y= 30 + 20\times 3.5 + 0.07\times 27 + (-30) \times 1 + 0.01\times 3.5\times 27 + 10\times 3.5\times 1$$
#
# $$y= 107.835$$
#
# #### For Non-Technical
# $$y= 30 + 20\times 3.5 + 0.07\times 27 + (-30) \times 0 + 0.01\times 3.5\times 27 + 10\times 3.5\times 0$$
#
# $$y= 102.835$$
#
# ### iii) For a fixed value of age and gpa, technical positions earn more than non-technical positions when the gpa is high enough
#
# #### True. Because :
# #### For Technical
# $$y= 30 + 20\times 3.5 + 0.07\times 27 + (-30) \times 1 + 0.01\times 3.5\times 27 + 10\times 3.5\times 1$$
#
# $$y= 107.835$$
#
# #### For Non-Technical
# $$y= 30 + 20\times 3.5 + 0.07\times 27 + (-30) \times 0 + 0.01\times 3.5\times 27 + 10\times 3.5\times 0$$
#
# $$y= 102.835$$
#
# ### iv) For a fixed value of age and gpa, non-technical positions earn more than technical positions when the gpa is high enough
#
# #### False. Because :
# #### For Technical
# $$y= 30 + 20\times 3.5+ 0.07\times 27 + (-30) \times 1 + 0.01\times 3.5\times 27 + 10\times 3.5\times 1$$
#
# $$y= 107.835$$
#
# #### For Non-Technical
# $$y= 30 + 20\times 4.0 + 0.07\times 27 + (-30) \times 0 + 0.01\times 4\times 27 + 10\times 4\times 0$$
#
# $$y= 102.835$$

# %% [markdown]
# ### Part B

# %% [markdown]
# #### For Technical
# $$y= 30 + 20\times 4.0 + 0.07\times 27 + (-30) \times 1 + 0.01\times 4\times 27 + 10\times 4\times 1$$
#
# $$y= 122.97$$
# #### For Non-Technical
# $$y= 30 + 20\times 4.0 + 0.07\times 27 + (-30) \times 0 + 0.01\times 4\times 27 + 10\times 4\times 0$$
#
# $$y= 112.97$$
