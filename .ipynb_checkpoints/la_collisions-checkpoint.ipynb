# %%
import pandas as pd
import seaborn as sns
import pandasql as ps
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/data.csv")
# Out:
# /Users/peterjmyers/Work/la_collisions/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (37,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df[["X", "Y", "collision_date", "collision_time", "day_of_week", "intersection", "weather_1", "location_type", "collision_severity", "number_killed", "number_injured", "party_count", "primary_coll_factor", "pcf_viol_category", "hit_and_run", "type_of_collision", "road_surface", "road_cond_1", "lighting", "control_device", "pedestrian_accident", "bicycle_accident", "motorcycle_accident", "truck_accident", "alcohol_involved", "count_ped_killed", "count_ped_injured", "count_bicyclist_killed", "count_bicyclist_injured"]]

# %%
df.iloc[0:5]
# Out:
#             X          Y            collision_date  collision_time  \
# 0 -118.333485  34.035515  2012-05-12T00:00:00.000Z             220
# 1 -118.401978  34.201237  2012-03-18T00:00:00.000Z            1700
# 2 -118.268378  34.113093  2014-06-15T00:00:00.000Z            1945
# 3 -118.473550  34.235558  2016-07-17T00:00:00.000Z             200
# 4 -118.400575  34.186689  2016-07-22T00:00:00.000Z             250
#
#    day_of_week intersection weather_1 location_type  collision_severity  \
# 0            6            N         A           NaN                   3
# 1            7            N         B           NaN                   4
# 2            7            N         A           NaN                   4
# 3            7            Y         A             R                   0
# 4            5            N         A             R                   0
#
#    number_killed           ...            control_device  pedestrian_accident  \
# ...

# %%
df['location_type'] = df['location_type']

# %%
query = """
SELECT
X, Y, collision_date, collision_time, day_of_week, intersection, weather_1, 
IFNULL(CASE WHEN location_type = "-" THEN 'N' ELSE  location_type),'N') AS location_type,
collision_severity, number_killed, number_injured, party_count, 
primary_coll_factor, pcf_viol_category, hit_and_run, type_of_collision, road_surface, 
road_cond_1, lighting, control_device, pedestrian_accident, bicycle_accident, 
motorcycle_accident, truck_accident, alcohol_involved, count_ped_killed, 
count_ped_injured, count_bicyclist_killed, count_bicyclist_injured
FROM df
"""

df = ps.sqldf(query, locals())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/Work/la_collisions/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~/Work/la_collisions/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# OperationalError: no such function: IF
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
df.iloc[0:4]
# Out:
#             X          Y            collision_date  collision_time  \
# 0 -118.333485  34.035515  2012-05-12T00:00:00.000Z             220
# 1 -118.401978  34.201237  2012-03-18T00:00:00.000Z            1700
# 2 -118.268378  34.113093  2014-06-15T00:00:00.000Z            1945
# 3 -118.473550  34.235558  2016-07-17T00:00:00.000Z             200
#
#    day_of_week intersection weather_1 location_type  collision_severity  \
# 0            6            N         A           NaN                   3
# 1            7            N         B           NaN                   4
# 2            7            N         A           NaN                   4
# 3            7            Y         A             R                   0
#
#    number_killed           ...            control_device  pedestrian_accident  \
# 0              0           ...                         A                  NaN
# 1              0           ...                         D                  NaN
# ...

# %%
df2 = ps.sqldf("""
SELECT location_type,
location_type is null
FROM df

""", locals())

# %%
df2.iloc[0:4]
# Out:
#   location_type  location_type is null
# 0          None                      1
# 1          None                      1
# 2          None                      1
# 3             R                      0

# %%
category_columns = []
i=0
for x in df.dtypes:
    if x == "object":
        category_columns.append(df.columns[i])
    i+=1
import math
COLUMNS = 3
plot_rows = math.ceil(len(category_columns)/COLUMNS)
fig, axs = plt.subplots(plot_rows,COLUMNS,figsize=(60/COLUMNS,60/COLUMNS))
col, row = 0, 0
for category in category_columns:    
    sns.countplot(y=category, hue="y", data=df, palette="Set2",ax=axs[row][col])
    col += 1
    if col == COLUMNS:
        row += 1
        col = 0

# %%
sns.plot(df["X"],["Y"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f0f3bacb738e> in <module>()
# ----> 1 sns.plot(df["X"],["Y"])
#
# AttributeError: module 'seaborn' has no attribute 'plot'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171533 entries, 0 to 171532
# Data columns (total 30 columns):
# X                          171533 non-null float64
# Y                          171533 non-null float64
# collision_date             171533 non-null object
# collision_time             171533 non-null int64
# day_of_week                171533 non-null int64
# intersection               171533 non-null object
# weather_1                  171533 non-null object
# weather_2                  171533 non-null object
# location_type              804 non-null object
# collision_severity         171533 non-null int64
# number_killed              171533 non-null int64
# number_injured             171533 non-null int64
# party_count                171533 non-null int64
# primary_coll_factor        171533 non-null object
# pcf_viol_category          171533 non-null object
# hit_and_run                171533 non-null object
# type_of_collision          171533 non-null object
# ...
